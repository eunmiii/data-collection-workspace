# %%
# !uv add matplotlib
# Out:
# Resolved 44 packages in 6ms
# Checked 43 packages in 4ms

# %%
import platform
import matplotlib.pyplot as plt

# os에 따른 한글 폰트 설정
if platform.system() == 'Windows' :
    plt.rc('font', family='Malgun Gothic')  # 윈도우 : 맑은 고딕
elif platform.system() == 'Darwin':
    plt.rc('font', family='AppleGothic')
else :
    plt.rc('font', family = 'NanumBarunGothic')

plt.rc('axes', unicode_minus=False)

# %%
# !uv add missingno
# Out:
# Resolved 44 packages in 2ms
# Checked 43 packages in 3ms

# %%
import missingno as msno

msno.matrix(df, figsize=(4,5), sparkline=False )
plt.show()

# %%
# !uv add scikit-learn
# Out:
# Resolved 48 packages in 2ms
# Checked 47 packages in 7ms
